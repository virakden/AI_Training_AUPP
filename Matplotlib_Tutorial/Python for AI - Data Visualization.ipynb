# %% [markdown]
# ## Data Visualization
#
# Matplotlib Tutorial: Fundamental Plots
#
# Matplotlib is a powerful Python library for creating static, animated, and interactive visualizations. In this tutorial series, we'll cover fundamental plots to get you started with Matplotlib.

# %% [markdown]
# ### 1.0 Matplotlib Package
#
# Matplotlib is a powerful Python library for creating static, animated, and interactive visualizations. In this tutorial series, we'll cover fundamental plots to get you started with Matplotlib.
#
#
# ```python
#
# pip install -U matplotlib
#
# ```

# %% [markdown]
# ##### Components of a Plot (Figure)
# source: https://personal.ntu.edu.sg/ehchua/programming/webprogramming/Python4_DataAnalysis.html#zz-8.3
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Line Plot
#
# A line plot is a basic type of plot used to visualize data points connected by straight line segments.

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plot
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Scatter Plot
#
# A scatter plot is used to visualize the relationship between two variables by representing data points as dots.

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plot
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bar Plot
#
# A bar plot is used to compare categorical data by displaying rectangular bars with heights proportional to the values they represent.

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

# Plot
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Histogram
#
# A histogram is used to represent the distribution of a continuous variable by dividing the data into bins and counting the number of observations in each bin.

# %%
import matplotlib.pyplot as plt

# Data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 7]

# Plot
plt.hist(data, bins=7)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Pie Chart
#
# A pie chart is used to represent the proportion of each category in a dataset as a slice of a circular pie.

# %%
import matplotlib.pyplot as plt

# Data
sizes = [30, 20, 15, 35]
labels = ['A', 'B', 'C', 'D']

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ### 2.0 GUIDING PRINCIPLES

# %% [markdown]
# ####  Purpose
#
#
# In order to effectively communicate the story represented in the data, choose charts that best convey the insight you wish to provide and apply styling carefully to support that message. Also, consider the context and the preferences of your audience.
#
# Goal - What are you trying to convey? Limit the visualization to one main theme with two or three supporting concepts to limit cognitive load and increase usefulness.
#
# Audience - How will the users of your visualization engage with it? Lay out the visualization and apply styles with device type, method of communication and cultural preferences in mind. If possible, test visualizations with users as part of the development process.
#
#
# Data - What type of information are you using the data to show? Additionally, what charts are your audiences most comfortable with? As much as possible, stick to common chart types (such as bar and line charts), especially when the audience's level of data literacy is unknown.

# %% [markdown]
# #### Accessibility
#
# Web accessibility is a priority and takes into consideration all disabilities that impact access to the web, including auditory, cognitive, neurological, physical, speech and visual. Limitations can be permanent (such as colorblindness), temporary (such as a broken arm) or situational (such as a noisy, distracting environment). To design data visualizations that are accessible to as many users as possible, it is especially important to consider the experience of people who have a vision deficiency or use technology such as screen readers, Braille keyboards or keyboard-only navigation.
#
# Color - Data visualizations often utilize color as a representation or to tell a story. Approximately 4.5% of people have some form of color-vision deficiency, so color can’t be the only way to explain or inform. Using the recommended color palette, which is designed to provide the best contrast, along with using appropriate chart types will aid in comprehension for all users.
#
# Text - Including a title that is short but descriptive enough to explain the visual and adding labels to important data points are key steps to creating an accessible data visualization. A summary will ensure that the takeaway from your data visualization is easily understood and consistent across all users.

# %% [markdown]
# ### 3.0 Seaborn
#
# Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive statistical graphics. In this tutorial series, we'll cover fundamental plots using Seaborn.

# %% [markdown]
# #### Line Plot
#
# Seaborn doesn't have a specific function for line plots like Matplotlib, but we can still achieve it using sns.lineplot().

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plot
sns.lineplot(x=x, y=y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Scatter Plot
#
# Seaborn's sns.scatterplot() function is used to create scatter plots.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plot
sns.scatterplot(x=x, y=y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bar Plot
#
# Seaborn's sns.barplot() function is used to create bar plots.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

# Plot
sns.barplot(x=categories, y=values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Histogram
#
# Seaborn's sns.histplot() function is used to create histograms.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 7]

# Plot
sns.histplot(data, bins=7)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Pie Chart
#
# Seaborn doesn't have a specific function for pie charts like Matplotlib, but you can use Matplotlib's plt.pie() function with Seaborn's styling.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
sizes = [30, 20, 15, 35]
labels = ['A', 'B', 'C', 'D']

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ### 4.0 Pandas
#
# Pandas provides functionality to create basic visualizations directly from DataFrames and Series objects. In this tutorial series, we'll cover various visualization techniques using Pandas.

# %% [markdown]
# #### Line Plot
# Pandas provides a simple interface to create line plots from DataFrame or Series data.

# %%
import pandas as pd

# Create a DataFrame
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 3, 5, 7, 11]}
df = pd.DataFrame(data)

# Plot
df.plot(x='x', y='y', kind='line', title='Line Plot')
# Out:
# <Axes: title={'center': 'Line Plot'}, xlabel='x'>

# %% [markdown]
# #### Scatter Plot
# Scatter plots can be created using the plot() function with kind='scatter'.

# %%
import pandas as pd

# Create a DataFrame
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 3, 5, 7, 11]}
df = pd.DataFrame(data)

# Plot
df.plot(x='x', y='y', kind='scatter', title='Scatter Plot')
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='x', ylabel='y'>

# %% [markdown]
# #### Bar Plot
# Bar plots can be created from DataFrame data using the plot() function with kind='bar'.

# %%
import pandas as pd

# Create a DataFrame
data = {'categories': ['A', 'B', 'C', 'D'], 'values': [23, 45, 56, 78]}
df = pd.DataFrame(data)

# Plot
df.plot(x='categories', y='values', kind='bar', title='Bar Plot')
# Out:
# <Axes: title={'center': 'Bar Plot'}, xlabel='categories'>

# %% [markdown]
# #### Histogram
#
# Histograms can be created using the plot() function with kind='hist'.

# %%
import pandas as pd

# Create a Series
data = pd.Series([1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 7])

# Plot
data.plot(kind='hist', bins=7, title='Histogram')
# Out:
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %% [markdown]
# #### Pie Chart
#
# Pandas provides a simple interface to create pie charts directly from Series data.

# %%
import pandas as pd

# Create a Series
data = pd.Series([30, 20, 15, 35], index=['A', 'B', 'C', 'D'], name='')
explode = (0, 0, 0, 0.1)   # "explode" the last slice by 0.2
# Plot
data.plot(kind='pie', autopct='%1.1f%%', title='Pie Chart', explode=explode)
# Out:
# <Axes: title={'center': 'Pie Chart'}>
